# %%
# import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Loading the Data

# %%
# Load meta file
df_meta = pd.read_csv('./Dataset/csv/meta.csv')

# load dicom info file
df_dicom = pd.read_csv('./Dataset/csv/dicom_info.csv')

# check image types in dataset
print("check image types in dataset: \n", df_dicom.SeriesDescription.unique(), "\n")


##### check image path in dataset

# cropped images
cropped_images = df_dicom[df_dicom.SeriesDescription=='cropped images'].image_path
print("check cropped images path in dataset: \n", cropped_images.head(1), "\n")

# full mammogram images
full_mammo = df_dicom[df_dicom.SeriesDescription=='full mammogram images'].image_path
print("check full mammogram images path in dataset: \n", full_mammo.head(1), "\n")

# ROI images
roi_img = df_dicom[df_dicom.SeriesDescription=='ROI mask images'].image_path
print("check full mammogram images path in dataset: \n", roi_img.head(1), "\n")


#### set correct image path for image types
imdir = './Dataset/jpeg'

# change directory path of images
cropped_images = cropped_images.replace('CBIS-DDSM/jpeg', imdir, regex=True)
full_mammo = full_mammo.replace('CBIS-DDSM/jpeg', imdir, regex=True)
roi_img = roi_img.replace('CBIS-DDSM/jpeg', imdir, regex=True)

# view new paths
print('Cropped Images paths:\n')
print(cropped_images.iloc[0], "\n")
print('Full mammo Images paths:\n')
print(full_mammo.iloc[0], "\n")
print('ROI Mask Images paths:\n')
print(roi_img.iloc[0], "\n")

# organize image paths
print("Re-organize image paths: ")
full_mammo_dict = dict()
cropped_images_dict = dict()
roi_img_dict = dict()

for dicom in full_mammo:
    key = dicom.split("/")[3]
    full_mammo_dict[key] = dicom
for dicom in cropped_images:
    key = dicom.split("/")[3]
    cropped_images_dict[key] = dicom
for dicom in roi_img:
    key = dicom.split("/")[3]
    roi_img[key] = dicom

# view keys
next(iter((full_mammo_dict.items())))
# Out:
# check image types in dataset:
#  ['cropped images' 'full mammogram images' nan 'ROI mask images']
#
# check cropped images path in dataset:
#  0    CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308...
# Name: image_path, dtype: object
#
# check full mammogram images path in dataset:
#  1    CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386...
# Name: image_path, dtype: object
#
# check full mammogram images path in dataset:
#  5    CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.153339...
# Name: image_path, dtype: object
#
# Cropped Images paths:
#
# ./Dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.129308726812851964007517874181459556304/1-172.jpg
#
# Full mammo Images paths:
#
# ./Dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg
#
# ROI Mask Images paths:
#
# ./Dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.153339052913121382622526066491844156138/2-270.jpg
#
# Re-organize image paths:
# ('1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849',
#  './Dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg')

# %%
# Load meta file
df_meta = pd.read_csv('./Dataset/csv/meta.csv')

# load dicom info file
df_dicom = pd.read_csv('./Dataset/csv/dicom_info.csv')

# check image types in dataset
print("check image types in dataset: \n", df_dicom.SeriesDescription.unique(), "\n")


##### check image path in dataset

# cropped images
cropped_images = df_dicom[df_dicom.SeriesDescription=='cropped images'].image_path
print("check cropped images path in dataset: \n", cropped_images.head(1), "\n")

# full mammogram images
full_mammo = df_dicom[df_dicom.SeriesDescription=='full mammogram images'].image_path
print("check full mammogram images path in dataset: \n", full_mammo.head(1), "\n")

# ROI images
roi_img = df_dicom[df_dicom.SeriesDescription=='ROI mask images'].image_path
print("check full mammogram images path in dataset: \n", roi_img.head(1), "\n")


#### set correct image path for image types
imdir = './Dataset/jpeg'

# change directory path of images
cropped_images = cropped_images.replace('CBIS-DDSM/jpeg', imdir, regex=True)
full_mammo = full_mammo.replace('CBIS-DDSM/jpeg', imdir, regex=True)
roi_img = roi_img.replace('CBIS-DDSM/jpeg', imdir, regex=True)

# view new paths
print('Cropped Images paths:\n')
print(cropped_images.iloc[0], "\n")
print('Full mammo Images paths:\n')
print(full_mammo.iloc[0], "\n")
print('ROI Mask Images paths:\n')
print(roi_img.iloc[0], "\n")

# organize image paths
print("Re-organize image paths: ")
full_mammo_dict = dict()
cropped_images_dict = dict()
roi_img_dict = dict()

for dicom in full_mammo:
    key = dicom.split("/")[3]
    full_mammo_dict[key] = dicom
for dicom in cropped_images:
    key = dicom.split("/")[3]
    cropped_images_dict[key] = dicom
for dicom in roi_img:
    key = dicom.split("/")[3]
    roi_img[key] = dicom

# view keys
next(iter((full_mammo_dict.items())))
# Out:
# check image types in dataset:
#  ['cropped images' 'full mammogram images' nan 'ROI mask images']
#
# check cropped images path in dataset:
#  0    CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308...
# Name: image_path, dtype: object
#
# check full mammogram images path in dataset:
#  1    CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386...
# Name: image_path, dtype: object
#
# check full mammogram images path in dataset:
#  5    CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.153339...
# Name: image_path, dtype: object
#
# Cropped Images paths:
#
# ./Dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.129308726812851964007517874181459556304/1-172.jpg
#
# Full mammo Images paths:
#
# ./Dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg
#
# ROI Mask Images paths:
#
# ./Dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.153339052913121382622526066491844156138/2-270.jpg
#
# Re-organize image paths:
# ('1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849',
#  './Dataset/jpeg/1.3.6.1.4.1.9590.100.1.2.248386742010678582309005372213277814849/1-249.jpg')

# %%
mass_train = pd.DataFrame
mass_test = pd.DataFrame

# load the mass dataset
mass_train = pd.read_csv('./Dataset/csv/mass_case_description_train_set.csv')
mass_test = pd.read_csv('./Dataset/csv/mass_case_description_test_set.csv')

# fix image paths
def fix_image_path(data):
    """correct dicom paths to correct image paths"""
    for index, img in enumerate(data.values):
        img_name = img[11].split("/")[2]
        data.iloc[index,11] = full_mammo_dict[img_name]
        img_name = img[12].split("/")[2]
        data.iloc[index,12] = cropped_images_dict[img_name]
        
# apply to datasets
fix_image_path(mass_train)
fix_image_path(mass_test)

print("check unique values in pathology column")
mass_train.pathology.unique()
# Out:
# check unique values in pathology column
# array(['MALIGNANT', 'BENIGN', 'BENIGN_WITHOUT_CALLBACK'], dtype=object)

# %%
# rename columns
mass_train = mass_train.rename(columns={'left or right breast': 'left_or_right_breast',
                                           'image view': 'image_view',
                                           'abnormality id': 'abnormality_id',
                                           'abnormality type': 'abnormality_type',
                                           'mass shape': 'mass_shape',
                                           'mass margins': 'mass_margins',
                                           'image file path': 'image_file_path',
                                           'cropped image file path': 'cropped_image_file_path',
                                           'ROI mask file path': 'ROI_mask_file_path'})

mass_test = mass_test.rename(columns={'left or right breast': 'left_or_right_breast',
                                           'image view': 'image_view',
                                           'abnormality id': 'abnormality_id',
                                           'abnormality type': 'abnormality_type',
                                           'mass shape': 'mass_shape',
                                           'mass margins': 'mass_margins',
                                           'image file path': 'image_file_path',
                                           'cropped image file path': 'cropped_image_file_path',
                                           'ROI mask file path': 'ROI_mask_file_path'})

# %%
# check for null values
mass_train.isnull().sum()
# Out:
# patient_id                  0
# breast_density              0
# left_or_right_breast        0
# image_view                  0
# abnormality_id              0
# abnormality_type            0
# mass_shape                  4
# mass_margins               43
# assessment                  0
# pathology                   0
# subtlety                    0
# image_file_path             0
# cropped_image_file_path     0
# ROI_mask_file_path          0
# dtype: int64

# %%
# fill in missing values using the backwards fill method
mass_train['mass_shape'] = mass_train['mass_shape'].fillna(method='bfill')
mass_train['mass_margins'] = mass_train['mass_margins'].fillna(method='bfill')

#check null values
mass_train.isnull().sum()
# Out:
# patient_id                 0
# breast_density             0
# left_or_right_breast       0
# image_view                 0
# abnormality_id             0
# abnormality_type           0
# mass_shape                 0
# mass_margins               0
# assessment                 0
# pathology                  0
# subtlety                   0
# image_file_path            0
# cropped_image_file_path    0
# ROI_mask_file_path         0
# dtype: int64

# %%
# fill in missing values using the backwards fill method
mass_test['mass_margins'] = mass_test['mass_margins'].fillna(method='bfill')

mass_test.isnull().sum()
# Out:
# patient_id                 0
# breast_density             0
# left_or_right_breast       0
# image_view                 0
# abnormality_id             0
# abnormality_type           0
# mass_shape                 0
# mass_margins               0
# assessment                 0
# pathology                  0
# subtlety                   0
# image_file_path            0
# cropped_image_file_path    0
# ROI_mask_file_path         0
# dtype: int64

# %%
# check datasets shape
print(f'Shape of mass_train: {mass_train.shape}')
print(f'Shape of mass_test: {mass_test.shape}')
# Out:
# Shape of mass_train: (1318, 14)
# Shape of mass_test: (378, 14)

# %%
# Display some images
import matplotlib.image as mpimg

# create function to display images
def display_images(column, number):
    """displays images in dataset"""
    # create figure and axes
    number_to_visualize = number
    rows = 1
    cols = number_to_visualize
    fig, axes = plt.subplots(rows, cols, figsize=(8, 6))
    
    # Loop through rows and display images
    for index, row in mass_train.head(number_to_visualize).iterrows():
        image_path = row[column]
        image = mpimg.imread(image_path)
        ax = axes[index]
        ax.imshow(image, cmap='gray')
        ax.set_title(f"{row['pathology']}")
        ax.axis('off')
    plt.tight_layout()
    plt.show()

print('Full Mammograms:\n')
display_images('image_file_path', 2)
print('Cropped Mammograms:\n')
display_images('cropped_image_file_path', 2)
# Out:
# Full Mammograms:
# Cropped Mammograms:

# %% [markdown]
# # Preprocessing of Images

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.10.1

# %%
if tf.test.is_gpu_available():
    # Get the list of available GPUs
    gpu_list = tf.config.list_physical_devices('GPU')
    print("GPU(s) available: ", len(gpu_list))
    # Ensure TensorFlow is using GPU acceleration
    print("TensorFlow is using GPU acceleration.")
else:
    print("No GPU available. TensorFlow is using CPU.")
# Out:
# WARNING:tensorflow:From C:\Users\haida\AppData\Local\Temp\ipykernel_30904\3367034781.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU(s) available:  1
# TensorFlow is using GPU acceleration.

# %%
import cv2
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator

# %%
def image_processor(image_path, target_size):
    """Preprocess images for CNN model"""
    absolute_image_path = os.path.abspath(image_path)
    image = cv2.imread(absolute_image_path)
    image = cv2.resize(image, (target_size[1], target_size[0]))

    ####
    ##In this case, we do the preprocessing before feed them into the data augmentation stage during training
    # Apply Gaussian Blur
    # image = apply_gaussian_blur(image)
    # Apply Perspective Transformation
    # image = apply_perspective_transform(image)
    # Apply Histogram Equalization
    # image = apply_histogram_equalization(image)
    ####

    # Normalize image (mean normalization)
    image_array = image.astype('float32') / 255.0
    
    return image_array

# %%
mass_train.shape
# Out:
# (1318, 14)

# %%
# Merge datasets
full_mass = pd.concat([mass_train, mass_test], axis=0)

# Define the target size
target_size = (224, 224, 3)

# Apply preprocessor to train data
full_mass['processed_images'] = full_mass['image_file_path'].apply(lambda x: image_processor(x, target_size))

# Create a binary mapper
class_mapper = {'MALIGNANT': 0, 'BENIGN': 1, 'BENIGN_WITHOUT_CALLBACK': 1} 

# Convert the processed_images column to an array
X_resized = np.array(full_mass['processed_images'].tolist())

# Apply class mapper to pathology column
full_mass['labels'] = full_mass['pathology'].replace(class_mapper)

# Check the number of classes
num_classes = len(full_mass['labels'].unique())

# Split data into train, test, and validation sets (70, 20, 10)
X_train, X_temp, y_train, y_temp = train_test_split(X_resized, full_mass['labels'].values, test_size=0.3, random_state=100)
X_test, X_val, y_test, y_val = train_test_split(X_temp, y_temp, test_size=0.33, random_state=100)

# Convert integer labels to one-hot encoded labels
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_val = to_categorical(y_val, num_classes)

# %%
X_resized.shape
# Out:
# (1696, 224, 224, 3)

# %%
X_temp.shape
# Out:
# (509, 224, 224, 3)

# %%
X_train.shape
# Out:
# (1187, 224, 224, 3)

# %%
y_train.shape
# Out:
# (1187, 2)

# %%
X_val.shape
# Out:
# (168, 224, 224, 3)

# %%
X_test.shape
# Out:
# (341, 224, 224, 3)

# %%
y_train
# Out:
# array([[0., 1.],
#        [1., 0.],
#        [1., 0.],
#        ...,
#        [0., 1.],
#        [0., 1.],
#        [0., 1.]], dtype=float32)

# %%
# Import necessary TensorFlow libraries
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, LeakyReLU, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adam, SGD, RMSprop, Nadam
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.applications import InceptionResNetV2, InceptionV3
from keras.utils import plot_model

# %%
# Augment data
train_datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest',
    channel_shift_range=20
    )

# apply augmentation to training data
image_size=224
train_data_augmented = train_datagen.flow(X_train, y_train, batch_size=32)

pretrain_model = InceptionResNetV2(input_shape=(image_size, image_size, 3), include_top=False, weights='imagenet')


for layer in pretrain_model.layers[:-3]:
    layer.trainable = False

# instantiate CNN model
model = tf.keras.Sequential([
    pretrain_model,
    GlobalAveragePooling2D(),
    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
    # BatchNormalization(),
    Dropout(0.5),
    Dense(2, activation='softmax')
])

# compile model
model.compile(loss='binary_crossentropy',
              optimizer=Nadam(learning_rate=0.00003),
              metrics=['accuracy'])

# Create a ModelCheckpoint callback
model_checkpoint = ModelCheckpoint(
    filepath='./checkpoint_filepatch',
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 5, 5, 1536)       54336736
#  onal)
#
#  global_average_pooling2d_1   (None, 1536)             0
#  (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
#  dense_2 (Dense)             (None, 128)               196736
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 54,533,730
# Trainable params: 3,393,410
# Non-trainable params: 51,140,320
# _________________________________________________________________

# %%
# train model
history = model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 50 , batch_size = 32)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 22s 281ms/step - loss: 3.0592 - accuracy: 0.5291 - val_loss: 2.9939 - val_accuracy: 0.5595
# Epoch 2/50
# 38/38 [==============================] - 7s 181ms/step - loss: 2.9524 - accuracy: 0.6074 - val_loss: 2.9314 - val_accuracy: 0.5536
# Epoch 3/50
# 38/38 [==============================] - 7s 185ms/step - loss: 2.8868 - accuracy: 0.6243 - val_loss: 2.8697 - val_accuracy: 0.5774
# Epoch 4/50
# 38/38 [==============================] - 7s 178ms/step - loss: 2.8050 - accuracy: 0.6453 - val_loss: 2.8079 - val_accuracy: 0.5893
# Epoch 5/50
# 38/38 [==============================] - 7s 177ms/step - loss: 2.7339 - accuracy: 0.6832 - val_loss: 2.7489 - val_accuracy: 0.6131
# Epoch 6/50
# 38/38 [==============================] - 7s 174ms/step - loss: 2.6734 - accuracy: 0.6858 - val_loss: 2.6901 - val_accuracy: 0.5952
# Epoch 7/50
# 38/38 [==============================] - 7s 175ms/step - loss: 2.6005 - accuracy: 0.7203 - val_loss: 2.6393 - val_accuracy: 0.6131
# Epoch 8/50
# 38/38 [==============================] - 7s 176ms/step - loss: 2.5352 - accuracy: 0.7355 - val_loss: 2.5924 - val_accuracy: 0.5774
# Epoch 9/50
# 38/38 [==============================] - 7s 176ms/step - loss: 2.4847 - accuracy: 0.7329 - val_loss: 2.5369 - val_accuracy: 0.6131
# Epoch 10/50
# 38/38 [==============================] - 7s 174ms/step - loss: 2.4273 - accuracy: 0.7439 - val_loss: 2.4923 - val_accuracy: 0.6190
# Epoch 11/50
# 38/38 [==============================] - 7s 173ms/step - loss: 2.3678 - accuracy: 0.7506 - val_loss: 2.4423 - val_accuracy: 0.6250
# Epoch 12/50
# 38/38 [==============================] - 7s 189ms/step - loss: 2.3094 - accuracy: 0.7818 - val_loss: 2.3983 - val_accuracy: 0.6369
# Epoch 13/50
# 38/38 [==============================] - 7s 180ms/step - loss: 2.2603 - accuracy: 0.7692 - val_loss: 2.3546 - val_accuracy: 0.6369
# Epoch 14/50
# 38/38 [==============================] - 7s 175ms/step - loss: 2.2195 - accuracy: 0.7616 - val_loss: 2.3131 - val_accuracy: 0.6190
# Epoch 15/50
# 38/38 [==============================] - 7s 174ms/step - loss: 2.1592 - accuracy: 0.7801 - val_loss: 2.2702 - val_accuracy: 0.6131
# Epoch 16/50
# 38/38 [==============================] - 7s 176ms/step - loss: 2.1135 - accuracy: 0.7852 - val_loss: 2.2288 - val_accuracy: 0.6310
# Epoch 17/50
# 38/38 [==============================] - 7s 176ms/step - loss: 2.0616 - accuracy: 0.7987 - val_loss: 2.1982 - val_accuracy: 0.6429
# Epoch 18/50
# 38/38 [==============================] - 7s 177ms/step - loss: 2.0233 - accuracy: 0.8003 - val_loss: 2.1579 - val_accuracy: 0.6310
# Epoch 19/50
# 38/38 [==============================] - 7s 178ms/step - loss: 1.9781 - accuracy: 0.8214 - val_loss: 2.1204 - val_accuracy: 0.6310
# Epoch 20/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.9366 - accuracy: 0.8054 - val_loss: 2.0908 - val_accuracy: 0.6310
# Epoch 21/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.8943 - accuracy: 0.8222 - val_loss: 2.0589 - val_accuracy: 0.6250
# Epoch 22/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.8471 - accuracy: 0.8315 - val_loss: 2.0290 - val_accuracy: 0.6369
# Epoch 23/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.8148 - accuracy: 0.8408 - val_loss: 1.9864 - val_accuracy: 0.6369
# Epoch 24/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.7690 - accuracy: 0.8441 - val_loss: 1.9728 - val_accuracy: 0.6548
# Epoch 25/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.7516 - accuracy: 0.8416 - val_loss: 1.9312 - val_accuracy: 0.6845
# Epoch 26/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.7126 - accuracy: 0.8475 - val_loss: 1.9027 - val_accuracy: 0.6488
# Epoch 27/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.6704 - accuracy: 0.8534 - val_loss: 1.8835 - val_accuracy: 0.6488
# Epoch 28/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.6331 - accuracy: 0.8787 - val_loss: 1.8660 - val_accuracy: 0.6369
# Epoch 29/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.6016 - accuracy: 0.8778 - val_loss: 1.8292 - val_accuracy: 0.6429
# Epoch 30/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.5658 - accuracy: 0.8745 - val_loss: 1.8111 - val_accuracy: 0.6488
# Epoch 31/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.5375 - accuracy: 0.8787 - val_loss: 1.7878 - val_accuracy: 0.6667
# Epoch 32/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.5107 - accuracy: 0.8812 - val_loss: 1.7671 - val_accuracy: 0.6667
# Epoch 33/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.4708 - accuracy: 0.8981 - val_loss: 1.7483 - val_accuracy: 0.6667
# Epoch 34/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.4535 - accuracy: 0.8939 - val_loss: 1.7264 - val_accuracy: 0.6786
# Epoch 35/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.4161 - accuracy: 0.8922 - val_loss: 1.7058 - val_accuracy: 0.6667
# Epoch 36/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.3849 - accuracy: 0.9065 - val_loss: 1.6919 - val_accuracy: 0.6488
# Epoch 37/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.3742 - accuracy: 0.8846 - val_loss: 1.6633 - val_accuracy: 0.6607
# Epoch 38/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.3377 - accuracy: 0.9048 - val_loss: 1.6486 - val_accuracy: 0.6667
# Epoch 39/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.3109 - accuracy: 0.9174 - val_loss: 1.6261 - val_accuracy: 0.6726
# Epoch 40/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.2876 - accuracy: 0.9200 - val_loss: 1.6245 - val_accuracy: 0.6369
# Epoch 41/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.2695 - accuracy: 0.9107 - val_loss: 1.6195 - val_accuracy: 0.6548
# Epoch 42/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.2414 - accuracy: 0.9217 - val_loss: 1.5849 - val_accuracy: 0.6667
# Epoch 43/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.2134 - accuracy: 0.9275 - val_loss: 1.5777 - val_accuracy: 0.6429
# Epoch 44/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.2010 - accuracy: 0.9225 - val_loss: 1.5560 - val_accuracy: 0.6548
# Epoch 45/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.1667 - accuracy: 0.9402 - val_loss: 1.5514 - val_accuracy: 0.6488
# Epoch 46/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.1514 - accuracy: 0.9393 - val_loss: 1.5366 - val_accuracy: 0.6488
# Epoch 47/50
# 38/38 [==============================] - 7s 177ms/step - loss: 1.1450 - accuracy: 0.9275 - val_loss: 1.5249 - val_accuracy: 0.6488
# Epoch 48/50
# 38/38 [==============================] - 7s 178ms/step - loss: 1.1047 - accuracy: 0.9528 - val_loss: 1.5118 - val_accuracy: 0.6607
# Epoch 49/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.0927 - accuracy: 0.9410 - val_loss: 1.5037 - val_accuracy: 0.6607
# Epoch 50/50
# 38/38 [==============================] - 7s 176ms/step - loss: 1.0668 - accuracy: 0.9528 - val_loss: 1.4879 - val_accuracy: 0.6429

# %%
model.evaluate(X_test, y_test)
# Out:
# 11/11 [==============================] - 2s 145ms/step - loss: 1.4403 - accuracy: 0.7067
# [1.4403393268585205, 0.7067448496818542]

# %%
import matplotlib.pyplot as plt

# Assuming 'history' contains the training history from model.fit

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)

# Print the test accuracy
print("Test Accuracy:", test_accuracy)

# Plot training, validation, and test accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Add a horizontal line for test accuracy
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation', 'Test'], loc='upper left')
plt.show()
# Out:
# 11/11 [==============================] - 2s 148ms/step - loss: 1.4403 - accuracy: 0.7067
# Test Accuracy: 0.7067448496818542

# %%
from sklearn.metrics import classification_report, confusion_matrix

# create labels for confusion matrix
cm_labels = ['MALIGNANT', 'BENIGN']

# obtain predictions
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

# convert predicted probabilities to class predictions
y_pred_classes_test = np.argmax(y_pred_test, axis=1)
y_pred_classes_train = np.argmax(y_pred_train, axis=1)

# Assuming y_test and y_val are in binary format (0 or 1)
y_true_classes_test = np.argmax(y_test, axis=1)
y_true_classes_train = np.argmax(y_train, axis=1)

# generate classification reports for test and val sets
test_report = classification_report(y_true_classes_test, y_pred_classes_test, target_names=cm_labels)
train_report = classification_report(y_true_classes_train, y_pred_classes_train, target_names=cm_labels)

# generate confusion matrices for test and validation sets
test_cm = confusion_matrix(y_true_classes_test, y_pred_classes_test)
train_cm = confusion_matrix(y_true_classes_train, y_pred_classes_train)

# create function to print confusion matrix
def plot_confusion_matrix(cm, labels, title):
    """plots a normalized confusion matrix as a heatmap."""
    # Calculate row sums
    row_sums = cm.sum(axis=1, keepdims=True)
    # Normalize confusion matrix
    normalized_cm = cm / row_sums

    plt.figure(figsize=(8, 6))
    sns.heatmap(normalized_cm, annot=True, fmt='.2%', cmap='Blues', cbar=False,
                xticklabels=labels, yticklabels=labels)
    plt.title(title, fontsize=14)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# print Train and Test reports and matrices
print(f"Train Set Classification report:\n {train_report}\n")
plot_confusion_matrix(train_cm, cm_labels, 'Train Set Confusion Matrix')
# Out:
# 11/11 [==============================] - 5s 160ms/step
# 38/38 [==============================] - 5s 144ms/step
# Train Set Classification report:
#                precision    recall  f1-score   support
#
#    MALIGNANT       0.96      0.99      0.97       561
#       BENIGN       0.99      0.96      0.98       626
#
#     accuracy                           0.97      1187
#    macro avg       0.97      0.98      0.97      1187
# weighted avg       0.98      0.97      0.97      1187

# %%
print(f"Test Set Classification report:\n {test_report}\n")
plot_confusion_matrix(test_cm, cm_labels, 'Test Set Confusion Matrix')
# Out:
# Test Set Classification report:
#                precision    recall  f1-score   support
#
#    MALIGNANT       0.67      0.65      0.66       150
#       BENIGN       0.73      0.75      0.74       191
#
#     accuracy                           0.71       341
#    macro avg       0.70      0.70      0.70       341
# weighted avg       0.71      0.71      0.71       341

# %%
from sklearn.metrics import roc_curve, auc

# Use the trained model to predict probabilities for the test set
y_pred_prob = model.predict(X_test)

# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_test[:, 1], y_pred_prob[:, 1])
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Print the AUC score
print(f'AUC: {roc_auc:.2f}')
# Out:
# 11/11 [==============================] - 2s 141ms/step
# AUC: 0.75

# %%
import random

# reverse class mapping
reverse_mapper = {v:k for k, v in class_mapper.items()}
prediction = model.predict(X_test)
# map predictions to class_names
predicted_class_indices = np.argmax(prediction, axis=1)
predicted_class_names = [reverse_mapper[i] for i in predicted_class_indices]

ground_truth_class_indices = np.argmax(y_test, axis=1)
ground_truth_class_names = [reverse_mapper[i] for i in ground_truth_class_indices]
# Out:
# 11/11 [==============================] - 2s 145ms/step

# %%
# display predicted class_names
num_image_visualize = min(3, len(X_test))

# create random indices to select images
random_indices = random.sample(range(len(X_test)), num_image_visualize)

# create subplots for images
fig, ax = plt.subplots(1, num_image_visualize, figsize=(15, 5))

for i, idx in enumerate(random_indices):
    ax[i].imshow(X_test[idx], cmap='gray')
    ax[i].set_title(f'Predicted: {predicted_class_names[idx]}', color='red')
    ax[i].text(0.3, -0.1, f'Truth: {ground_truth_class_names[idx]}', ha='center', va='center', 
              transform=ax[i].transAxes, color='blue')
    ax[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# Save the entire model (architecture, optimizer, and learned weights)
model.save('./CBIS_DDSM_CNN_Model_1')

# You can also save only the weights if you prefer
model.save_weights('./CBIS_DDSM_CNN_Model_1_weights')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 244). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./CBIS_DDSM_CNN_Model_1\assets
# INFO:tensorflow:Assets written to: ./CBIS_DDSM_CNN_Model_1\assets
